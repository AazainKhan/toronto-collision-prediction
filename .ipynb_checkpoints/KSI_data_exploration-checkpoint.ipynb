# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('KSI.csv')

# %%
# rows and columns
print(df.shape)
# Out:
# (18194, 57)

# %%
print(df.head())
# Out:
#               X             Y   INDEX_    ACCNUM  YEAR  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658.0  2006
# 1 -8.844611e+06  5.412414e+06  3387731  892658.0  2006
# 2 -8.816480e+06  5.434843e+06  3388101  892810.0  2006
# 3 -8.829728e+06  5.419071e+06  3389067  893184.0  2006
# 4 -8.816480e+06  5.434843e+06  3388102  892810.0  2006
#
#                      DATE  TIME          STREET1         STREET2 OFFSET  ...  \
# 0  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 1  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 2  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
# 3  2006/01/01 05:00:00+00   236     WOODBINE AVE     O CONNOR DR    NaN  ...
# 4  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
#
#   AG_DRIV REDLIGHT  ALCOHOL  DISABILITY  HOOD_158 NEIGHBOURHOOD_158 HOOD_140  \
# 0     Yes      NaN      NaN         NaN        88   High Park North       88
# 1     Yes      NaN      NaN         NaN        88   High Park North       88
# 2     Yes      Yes      NaN         NaN       146      Malvern East      132
# 3     Yes      NaN      Yes         NaN        60  Woodbine-Lumsden       60
# 4     Yes      Yes      NaN         NaN       146      Malvern East      132
#
#        NEIGHBOURHOOD_140 DIVISION ObjectId
# 0   High Park North (88)      D11        1
# 1   High Park North (88)      D11        2
# 2          Malvern (132)      D42        3
# 3  Woodbine-Lumsden (60)      D55        4
# 4          Malvern (132)      D42        5
#
# [5 rows x 57 columns]

# %%
# column types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18194 entries, 0 to 18193
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  18194 non-null  float64
#  1   Y                  18194 non-null  float64
#  2   INDEX_             18194 non-null  int64
#  3   ACCNUM             13264 non-null  float64
#  4   YEAR               18194 non-null  int64
#  5   DATE               18194 non-null  object
#  6   TIME               18194 non-null  int64
#  7   STREET1            18194 non-null  object
#  8   STREET2            16510 non-null  object
#  9   OFFSET             3402 non-null   object
#  10  ROAD_CLASS         17818 non-null  object
#  11  DISTRICT           18089 non-null  object
#  12  WARDNUM            17332 non-null  float64
#  13  LATITUDE           18194 non-null  float64
#  14  LONGITUDE          18194 non-null  float64
#  15  LOCCOORD           18099 non-null  object
#  16  ACCLOC             12744 non-null  object
#  17  TRAFFCTL           18160 non-null  object
#  18  VISIBILITY         18174 non-null  object
#  19  LIGHT              18194 non-null  object
#  20  RDSFCOND           18169 non-null  object
#  21  ACCLASS            18189 non-null  object
#  22  IMPACTYPE          18190 non-null  object
#  23  INVTYPE            18178 non-null  object
#  24  INVAGE             18194 non-null  object
#  25  INJURY             9627 non-null   object
#  26  FATAL_NO           827 non-null    float64
#  27  INITDIR            13142 non-null  object
#  28  VEHTYPE            14966 non-null  object
#  29  MANOEUVER          10534 non-null  object
#  30  DRIVACT            9243 non-null   object
#  31  DRIVCOND           9240 non-null   object
#  32  PEDTYPE            3060 non-null   object
#  33  PEDACT             3082 non-null   object
#  34  PEDCOND            3084 non-null   object
#  35  CYCLISTYPE         774 non-null    object
#  36  CYCACT             766 non-null    object
#  37  CYCCOND            765 non-null    object
#  38  PEDESTRIAN         7354 non-null   object
#  39  CYCLIST            1906 non-null   object
#  40  AUTOMOBILE         16550 non-null  object
#  41  MOTORCYCLE         1587 non-null   object
#  42  TRUCK              1122 non-null   object
#  43  TRSN_CITY_VEH      1110 non-null   object
#  44  EMERG_VEH          43 non-null     object
#  45  PASSENGER          6906 non-null   object
#  46  SPEEDING           2575 non-null   object
#  47  AG_DRIV            9460 non-null   object
#  48  REDLIGHT           1520 non-null   object
#  49  ALCOHOL            788 non-null    object
#  50  DISABILITY         486 non-null    object
#  51  HOOD_158           18194 non-null  object
#  52  NEIGHBOURHOOD_158  18194 non-null  object
#  53  HOOD_140           18194 non-null  object
#  54  NEIGHBOURHOOD_140  18194 non-null  object
#  55  DIVISION           18194 non-null  object
#  56  ObjectId           18194 non-null  int64
# dtypes: float64(7), int64(4), object(46)
# memory usage: 7.9+ MB

# %%
# statistical summary (mean, std, min, max, etc.)
print(df.describe())
# Out:
#                   X             Y        INDEX_        ACCNUM          YEAR  \
# count  1.819400e+04  1.819400e+04  1.819400e+04  1.326400e+04  18194.000000
# mean  -8.838345e+06  5.420748e+06  3.818870e+07  4.248444e+08   2012.934869
# std    1.162533e+04  8.682160e+03  3.726463e+07  1.065503e+09      4.754258
# min   -8.865305e+06  5.402162e+06  3.363207e+06  2.530100e+04   2006.000000
# 25%   -8.846591e+06  5.413242e+06  5.391370e+06  1.021229e+06   2009.000000
# 50%   -8.838448e+06  5.419556e+06  7.644612e+06  1.197308e+06   2012.000000
# 75%   -8.829671e+06  5.427813e+06  8.078261e+07  1.365020e+06   2017.000000
# max   -8.807929e+06  5.443099e+06  8.170606e+07  4.008024e+09   2022.000000
#
#                TIME       WARDNUM      LATITUDE     LONGITUDE    FATAL_NO  \
# count  18194.000000  1.733200e+04  18194.000000  18194.000000  827.000000
# mean    1362.615917  2.521028e+03     43.710459    -79.396201   29.073761
# std      630.816048  1.844803e+05      0.056369      0.104432   17.803627
# min        0.000000  1.000000e+00     43.589678    -79.638390    1.000000
# 25%      920.000000  7.000000e+00     43.661727    -79.470280   14.000000
# 50%     1450.000000  1.300000e+01     43.702745    -79.397132   28.000000
# 75%     1850.000000  2.200000e+01     43.756345    -79.318286   42.000000
# max     2359.000000  1.716222e+07     43.855445    -79.122974   78.000000
#
#            ObjectId
# count  18194.000000
# mean    9097.500000
# std     5252.299734
# min        1.000000
# 25%     4549.250000
# 50%     9097.500000
# 75%    13645.750000
# max    18194.000000

# %%
# null values
print(df.isnull().sum())
# Out:
# X                        0
# Y                        0
# INDEX_                   0
# ACCNUM                4930
# YEAR                     0
# DATE                     0
# TIME                     0
# STREET1                  0
# STREET2               1684
# OFFSET               14792
# ROAD_CLASS             376
# DISTRICT               105
# WARDNUM                862
# LATITUDE                 0
# LONGITUDE                0
# LOCCOORD                95
# ACCLOC                5450
# TRAFFCTL                34
# VISIBILITY              20
# LIGHT                    0
# RDSFCOND                25
# ACCLASS                  5
# IMPACTYPE                4
# INVTYPE                 16
# INVAGE                   0
# INJURY                8567
# FATAL_NO             17367
# INITDIR               5052
# VEHTYPE               3228
# MANOEUVER             7660
# DRIVACT               8951
# DRIVCOND              8954
# PEDTYPE              15134
# PEDACT               15112
# PEDCOND              15110
# CYCLISTYPE           17420
# CYCACT               17428
# CYCCOND              17429
# PEDESTRIAN           10840
# CYCLIST              16288
# AUTOMOBILE            1644
# MOTORCYCLE           16607
# TRUCK                17072
# TRSN_CITY_VEH        17084
# EMERG_VEH            18151
# PASSENGER            11288
# SPEEDING             15619
# AG_DRIV               8734
# REDLIGHT             16674
# ALCOHOL              17406
# DISABILITY           17708
# HOOD_158                 0
# NEIGHBOURHOOD_158        0
# HOOD_140                 0
# NEIGHBOURHOOD_140        0
# DIVISION                 0
# ObjectId                 0
# dtype: int64

# %%
# Plot histogram
df.hist(bins=50, figsize=(20, 20))
plt.show()

# Plot correlation matrix
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='RdYlGn')
plt.show()

# %%
# Double check if we need to use these columns to train the model based on the requirement
# yes and no columns
bool_cols = [df.columns[col] for col in range(38, 51)]
bool_cols
# Out:
# ['PEDESTRIAN',
#  'CYCLIST',
#  'AUTOMOBILE',
#  'MOTORCYCLE',
#  'TRUCK',
#  'TRSN_CITY_VEH',
#  'EMERG_VEH',
#  'PASSENGER',
#  'SPEEDING',
#  'AG_DRIV',
#  'REDLIGHT',
#  'ALCOHOL',
#  'DISABILITY']

# %%
# Fill missing values with 'No' in boolean columns
df[bool_cols] = df[bool_cols].fillna('No')
df[bool_cols]
# Out:
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0            Yes      No        Yes         No    No            No        No
# 1            Yes      No        Yes         No    No            No        No
# 2             No      No        Yes        Yes    No            No        No
# 3             No      No        Yes         No    No            No        No
# 4             No      No        Yes        Yes    No            No        No
# ...          ...     ...        ...        ...   ...           ...       ...
# 18189        Yes      No        Yes         No    No            No        No
# 18190        Yes      No        Yes         No    No            No        No
# 18191        Yes      No        Yes         No    No            No        No
# 18192        Yes      No        Yes         No    No            No        No
# 18193        Yes      No        Yes         No    No            No        No
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY
# 0            No       No     Yes       No      No         No
# 1            No       No     Yes       No      No         No
# 2            No       No     Yes      Yes      No         No
# 3           Yes      Yes     Yes       No     Yes         No
# 4            No       No     Yes      Yes      No         No
# ...         ...      ...     ...      ...     ...        ...
# 18189        No       No     Yes       No      No         No
# 18190        No       No     Yes       No      No         No
# 18191        No       No     Yes       No      No         No
# 18192        No       No      No       No      No         No
# 18193        No       No      No       No      No         No
#
# [18194 rows x 13 columns]

# %%
# Drop columns having more than 80% missing values
missing_percentages = (df.isnull().sum() / len(df)) * 100
columns_to_drop = missing_percentages[missing_percentages > 80].index
df = df.drop(columns=columns_to_drop)

# %%
# From correlation matrix, we can see that 'X' and 'LONGITUDE', 'Y' and 'LATITUDE' are highly correlated.
# So, we will drop x and y columns
columns_to_drop = ['X', 'Y']
df = df.drop(columns=columns_to_drop)

# %%
# Drop columns which may not be useful for analysis
# 'ObjectId' and 'INDEX_' are unique identifiers and not useful for analysis
# 'ACCNUM' is also unique identifier and not useful for analysis
# initial direction of vehicle 'INITDIR' is not useful for analysis
# we dont need street names 'STREET1' and 'STREET2' for analysis beacasue we have 'neighbourhood' column
# 'DISTRICT' and 'WARDNUM' are not useful for analysis beacuse we have 'neighbourhood' column
# unique identifier 'DIVISION' is not useful for analysis
# 'HOOD_158' and 'HOOD_140' are not useful for analysis because they are unique identifiers
# 'INJURY' is not useful for analysis because it is the target variable
columns_to_drop = ['ObjectId', 'INDEX_', 'ACCNUM', 'INITDIR', 'STREET1',
                   'STREET2', 'DISTRICT', 'WARDNUM', 'DIVISION', 'HOOD_158', 'HOOD_140', 'INJURY']
# 'INJURY' feature which might be dropped depends on the accuracy score of model
df = df.drop(columns=columns_to_drop)

# %%
# In 'NEIGHBOURHOOD_140', the values contain number inside brackets. We can remove the number inside brackets.
df['NEIGHBOURHOOD_140'] = df['NEIGHBOURHOOD_140'].str.replace(r"\(.*\)", "")

# %%
# Convert 'property' to 'non fatal'
df['ACCLASS'] = df['ACCLASS'].str.replace(
    "Property Damage Only", "Non-Fatal Injury")

# %%
# columns <3% missing values from the categorical, drop it

print(df.shape)
# Out:
# (18194, 35)

# %%
df.plot.scatter(x='LONGITUDE',y='LATITUDE')
plt.show()

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
categorical_columns
# Out:
# Index(['DATE', 'ROAD_CLASS', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE',
#        'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDESTRIAN', 'CYCLIST',
#        'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH',
#        'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY',
#        'NEIGHBOURHOOD_158', 'NEIGHBOURHOOD_140'],
#       dtype='object')

# %%
df['ROAD_CLASS'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='ROAD_CLASS'>

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df['WEEKDAY'] = df['DATE'].dt.day_name()  # Extract day of the week
df['DAY'] = df['DATE'].dt.day  # Extract day
df['MONTH'] = df['DATE'].dt.month_name()  # Extract month
df['YEAR'] = df['DATE'].dt.year  # Extract year

# Plotting number of accidents by day of the week
df['WEEKDAY'].value_counts().plot(kind='bar')
plt.title('Accidents by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Accidents')
plt.show()



# To investigate the vehicle type and accidents
# Assuming the column 'VEHTYPE' indicates the type of vehicle
vehtype_injury_counts = df.groupby('VEHTYPE')['INJURY'].value_counts().unstack()
vehtype_injury_counts.plot(kind='bar', stacked=True)  # Using a stacked bar chart to show injury counts by vehicle type
plt.title('Injuries by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Injuries')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 19
#      12 plt.show()
#      14 # Similarly, you can create bar charts for 'DAY', 'MONTH', and 'YEAR'
#      15 # ...
#      16
#      17 # To investigate the vehicle type and accidents
#      18 # Assuming the column 'VEHTYPE' indicates the type of vehicle
# ---> 19 vehtype_injury_counts = df.groupby('VEHTYPE')['INJURY'].value_counts().unstack()
#      20 vehtype_injury_counts.plot(kind='bar', stacked=True)  # Using a stacked bar chart to show injury counts by vehicle type
#      21 plt.title('Injuries by Vehicle Type')
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: INJURY'

# %%
print(df.columns)
# Out:
# Index(['YEAR', 'DATE', 'TIME', 'ROAD_CLASS', 'LATITUDE', 'LONGITUDE',
#        'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND',
#        'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'VEHTYPE', 'MANOEUVER',
#        'DRIVACT', 'DRIVCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE',
#        'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER',
#        'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY',
#        'NEIGHBOURHOOD_158', 'NEIGHBOURHOOD_140', 'WEEKDAY', 'DAY', 'MONTH'],
#       dtype='object')
